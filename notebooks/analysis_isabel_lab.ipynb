# %% [markdown]
# # Analysis of Isabel's lab data
#
# > Marcos Duarte
# > [Laboratory of Biomechanics and Motor Control](http://demotu.org/)
# > Federal University of ABC, Brazil

# %% [markdown]
# > EZC3D is an easy to use reader, modifier and writer for C3D format files.
# > https://github.com/pyomeca/ezc3d

# %%
import numpy as np
import pandas as pd
# %matplotlib notebook
#%matplotlib widget
import matplotlib as mpl
import matplotlib.pyplot as plt
import sys, os
import glob

# %load_ext autoreload
# %autoreload 2

sys.path.insert(1, r'./../functions')
from read_c3d import read_c3d

# %%
path2 = '/mnt/A/BMClab/Projects/Lab_Isabel/'
# files in the directory:
filenames = glob.glob(os.path.join(path2, '*.c3d'), recursive=True)
filenames.sort()
print('Number of files:', len(filenames))
# Out:
# Number of files: 20

# %%
an, pt = read_c3d(filenames[0], analog='all', point='all', rot=[[0,1,0],[0,0,1],[1,0,0]])

# %%
an
# Out:
#          Force.Fx1    Force.Fy1  Force.Fz1    Moment.Mx1   Moment.My1  \
# Time
# 0.000   -87.648636  -827.517456  15.873606 -36343.226562  4711.354492
# 0.001   -96.135757  -823.921814  29.621464 -32616.820312  3037.053467
# 0.002  -112.389313  -843.562561  33.013557 -32298.835938  2743.376953
# 0.003  -119.423714  -873.253052  30.512823 -35359.796875  2189.146484
# 0.004  -124.779633  -897.676453  35.848347 -38703.609375  -472.314575
# ...            ...          ...        ...           ...          ...
# 14.525  -77.540871 -1108.282959 -18.941971  15724.710938 -8166.666992
# 14.526  -84.009270 -1137.070435 -14.424066  15179.712891 -6411.000977
# 14.527  -91.446159 -1165.276367  -7.765492  14946.718750 -5397.306641
# 14.528  -86.824463 -1184.000854 -14.543006  15632.059570 -5416.066406
# 14.529  -83.755371 -1195.787231  -9.294790  20029.648438 -7003.922363
#
#            Moment.Mz1  Force.Fx2  Force.Fy2  Force.Fz2   Moment.Mx2  \
# Time
# ...

# %%
pt
# Out:
# Marker           PELO                                PELA              \
# Coordinate          X           Y           Z           X           Y
# XYZ                X1          Y1          Z1          X2          Y2
# Time
# 0.00        54.936520  896.594971  395.866577  218.053574  867.767273
# 0.01        53.518341  890.475525  396.593689  216.832367  862.669495
# 0.02        52.239918  885.557190  397.206940  215.703278  858.551636
# 0.03        51.103809  881.834229  397.705261  214.673752  855.412048
# 0.04        50.112267  879.298401  398.088684  213.749756  853.245911
# ...               ...         ...         ...         ...         ...
# 14.48       32.390778  928.463074  393.353882  194.385529  893.817200
# 14.49       32.007904  921.109680  393.196045  194.505585  889.047058
# 14.50       31.428072  912.505127  393.015503  194.456284  883.460205
# 14.51       30.656185  902.660767  392.806091  194.216827  877.068481
# ...

# %%
pt.columns.values
# Out:
# array([('PELO', 'X', 'X1'), ('PELO', 'Y', 'Y1'), ('PELO', 'Z', 'Z1'),
#        ('PELA', 'X', 'X2'), ('PELA', 'Y', 'Y2'), ('PELA', 'Z', 'Z2'),
#        ('PELL', 'X', 'X3'), ('PELL', 'Y', 'Y3'), ('PELL', 'Z', 'Z3'),
#        ('PELP', 'X', 'X4'), ('PELP', 'Y', 'Y4'), ('PELP', 'Z', 'Z4'),
#        ('LFEO', 'X', 'X5'), ('LFEO', 'Y', 'Y5'), ('LFEO', 'Z', 'Z5'),
#        ('LFEA', 'X', 'X6'), ('LFEA', 'Y', 'Y6'), ('LFEA', 'Z', 'Z6'),
#        ('LFEL', 'X', 'X7'), ('LFEL', 'Y', 'Y7'), ('LFEL', 'Z', 'Z7'),
#        ('LFEP', 'X', 'X8'), ('LFEP', 'Y', 'Y8'), ('LFEP', 'Z', 'Z8'),
#        ('LTIO', 'X', 'X9'), ('LTIO', 'Y', 'Y9'), ('LTIO', 'Z', 'Z9'),
#        ('LTIA', 'X', 'X10'), ('LTIA', 'Y', 'Y10'), ('LTIA', 'Z', 'Z10'),
#        ('LTIL', 'X', 'X11'), ('LTIL', 'Y', 'Y11'), ('LTIL', 'Z', 'Z11'),
#        ('LTIP', 'X', 'X12'), ('LTIP', 'Y', 'Y12'), ('LTIP', 'Z', 'Z12'),
#        ('LFOO', 'X', 'X13'), ('LFOO', 'Y', 'Y13'), ('LFOO', 'Z', 'Z13'),
# ...

# %%
markers = list(pt.columns.levels[0])
markers
# Out:
# ['*77',
#  '*78',
#  '*79',
#  'LANK',
#  'LASI',
#  'LAbsAnkleAngle',
#  'LAnkleAngles',
#  'LAnkleForce',
#  'LAnkleMoment',
#  'LAnklePower',
#  'LFCD',
#  'LFEA',
#  'LFEL',
#  'LFEO',
#  'LFEP',
#  'LFMB',
#  'LFMH',
#  'LFOA',
#  'LFOL',
#  'LFOO',
#  'LFOP',
#  'LFootProgressAngles',
#  'LGroundReactionForce',
#  'LGroundReactionMoment',
#  'LHEE',
#  'LHF',
#  'LHipAngles',
#  'LHipForce',
#  'LHipMoment',
#  'LHipPower',
#  'LKNE',
#  'LKneeAngles',
#  'LKneeForce',
#  'LKneeMoment',
#  'LKneePower',
#  'LMM',
#  'LNormalisedGRF',
#  'LPM',
#  'LPSI',
#  'LPT',
#  'LPelvisAngles',
#  'LSMB',
#  'LST',
#  'LTHI',
#  'LTIA',
#  'LTIB',
#  'LTIL',
#  'LTIO',
#  'LTIP',
#  'LTN',
#  'LTOA',
#  'LTOE',
#  'LTOL',
#  'LTOO',
#  'LTOP',
#  'LTT',
#  'LVMB',
#  'LVMH',
#  'PELA',
#  'PELL',
#  'PELO',
#  'PELP',
#  'RANK',
#  'RASI',
#  'RAbsAnkleAngle',
#  'RAnkleAngles',
#  'RAnkleForce',
#  'RAnkleMoment',
#  'RAnklePower',
#  'RFEA',
#  'RFEL',
#  'RFEO',
#  'RFEP',
#  'RFMB',
# ...

# %%
markers = pt.columns.get_level_values('Marker').values
markers
# Out:
# array(['PELO', 'PELO', 'PELO', 'PELA', 'PELA', 'PELA', 'PELL', 'PELL',
#        'PELL', 'PELP', 'PELP', 'PELP', 'LFEO', 'LFEO', 'LFEO', 'LFEA',
#        'LFEA', 'LFEA', 'LFEL', 'LFEL', 'LFEL', 'LFEP', 'LFEP', 'LFEP',
#        'LTIO', 'LTIO', 'LTIO', 'LTIA', 'LTIA', 'LTIA', 'LTIL', 'LTIL',
#        'LTIL', 'LTIP', 'LTIP', 'LTIP', 'LFOO', 'LFOO', 'LFOO', 'LFOA',
#        'LFOA', 'LFOA', 'LFOL', 'LFOL', 'LFOL', 'LFOP', 'LFOP', 'LFOP',
#        'LTOO', 'LTOO', 'LTOO', 'LTOA', 'LTOA', 'LTOA', 'LTOL', 'LTOL',
#        'LTOL', 'LTOP', 'LTOP', 'LTOP', 'RFEO', 'RFEO', 'RFEO', 'RFEA',
#        'RFEA', 'RFEA', 'RFEL', 'RFEL', 'RFEL', 'RFEP', 'RFEP', 'RFEP',
#        'RTIO', 'RTIO', 'RTIO', 'RTIA', 'RTIA', 'RTIA', 'RTIL', 'RTIL',
#        'RTIL', 'RTIP', 'RTIP', 'RTIP', 'RFOO', 'RFOO', 'RFOO', 'RFOA',
#        'RFOA', 'RFOA', 'RFOL', 'RFOL', 'RFOL', 'RFOP', 'RFOP', 'RFOP',
#        'RTOO', 'RTOO', 'RTOO', 'RTOA', 'RTOA', 'RTOA', 'RTOL', 'RTOL',
# ...

# %%
pt[['RTOE', 'LTOE']]
# Out:
# Marker            RTOE                                LTOE              \
# Coordinate           X           Y           Z           X           Y
# XYZ                X52         Y52         Z52         X46         Y46
# Time
# 0.00        283.401337   28.468462  432.502411 -416.425415  163.511856
# 0.01        259.726929   28.606787  431.904388 -401.774597  167.531677
# 0.02        235.695389   28.794304  431.462311 -384.973877  169.435272
# 0.03        211.302399   29.026199  431.174011 -366.023956  169.233215
# 0.04        186.536789   29.289618  431.033203 -344.926117  166.956909
# ...                ...         ...         ...         ...         ...
# 14.48      -416.276093  131.536819  467.570679  326.068024   57.734768
# 14.49      -411.402466  141.316208  474.505707  304.196625   50.069393
# 14.50      -403.578522  150.267883  481.426697  277.753815   40.981457
# 14.51      -392.807343  158.336121  488.304657  246.807129   30.499485
# ...

# %%
plt.close('all')
ax = pt.plot(y=['RTOE', 'LTOE'], subplots=True, sharex=True, figsize=(8, 4), rot=0,
             title='A plot of kinematics')
plt.subplots_adjust(left=.05, right=.99, top=.95, bottom=.1, wspace=0, hspace=0)
#plt.tight_layout(pad=.05, h_pad=0, w_pad=0, rect=[0, 0, .99, .95])
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
pt[['RTOE', 'LTOE']].mean()
# Out:
# Marker  Coordinate  XYZ
# RTOE    X           X52    -48.604509
#         Y           Y52     73.409332
#         Z           Z52    454.204458
# LTOE    X           X46    -67.194364
#         Y           Y46     75.115357
#         Z           Z46    322.441043
# dtype: float64

# %%
copx = pt['RGroundReactionMoment']['Z'].values/pt['RGroundReactionForce']['Y'].values

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,4))
ax.plot(copx)
plt.subplots_adjust(left=.05, right=.99, top=.95, bottom=.1, wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
ax = pt.plot(y=['RGroundReactionForce', 'RGroundReactionMoment'],
             subplots=True, sharex=True, figsize=(8, 5), rot=0,
             title='A plot of RGroundReaction')
plt.subplots_adjust(left=.05, right=.99, top=.95, bottom=.1, wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
